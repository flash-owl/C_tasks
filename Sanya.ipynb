# %%
# %load_ext cython

# %%
# %%cython
# x = 1
# def func(n):
#     if n == 0:
#         return 1
#     elif n == 1:
#         return x
#     else:
#         return ((2*n+1)/(n-1))*func(n-1) - ((n+1)/(n+2))*func(n-2)

# %%
# %timeit func(10)
# Out:
# 524.45 µs ± 771 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%cython
# cdef int x = 1
# cdef double func(int n):
#     if n == 0:
#         return 1
#     elif n == 1:
#         return x
#     else:
#         return ((2*n+1)/(n-1))*func(n-1) - ((n+1)/(n+2))*func(n-2)

# %%
# %timeit func(10)
# Out:
# 167 µs ± 665 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
